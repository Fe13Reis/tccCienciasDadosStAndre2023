# %%
# Importando as bibliotecas
import pandas as pd
import statsmodels.formula.api as smf
import statsmodels.stats.api as sms
import scipy.stats as stats
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import seaborn as sns
import os

# %%
# Carregando a base de dados
df = pd.read_csv('Leste2.csv', sep=';')

# %%
df
# Out:
#                   Nome  Domicilios  Populacao  RendaTotal  RendaMediaFamiliar  \
# 0              Vila Ré        8982      26818    30053611                3346
# 1   Ermelino Matarazzo       22958      71109    74811502                3177
# 2  São Miguel Paulista        7580      24124    26124920                3399
# 3        Jardim Romano       10206      33296    28123781                2704
# 4       Itaim Paulista       15181      45915    37151617                2447
# 5    Cidade Tiradentes       48217     152866   114926868                2368
# 6           São Mateus       21428      66948    70479006                3218
#
#    RendaPerCapita  MatriculasEscolares  Empregos  ViagensDeBicicleta
# 0            1121                 4996      9021                 902
# 1            1052                11591     14445                1510
# 2            1083                 8538      7763                 137
# 3             845                 5687      9162                1113
# 4             809                15804     15898                 479
# 5             752                39971     31893                 660
# 6            1053                 9921     21738                1276

# %%
df.dtypes
# Out:
# Nome                   object
# Domicilios              int64
# Populacao               int64
# RendaTotal              int64
# RendaMediaFamiliar      int64
# RendaPerCapita          int64
# MatriculasEscolares     int64
# Empregos                int64
# ViagensDeBicicleta      int64
# dtype: object

# %%
# GRÁFICO DE CORRELAÇÃO
sns.pairplot(df)

# %%
correlacoes = df.corr(method='pearson')
correlacoes
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_7600\3000246978.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlacoes = df.corr(method='pearson')
#                      Domicilios  Populacao  RendaTotal  RendaMediaFamiliar  \
# Domicilios             1.000000   0.999671    0.970123           -0.555408
# Populacao              0.999671   1.000000    0.967987           -0.557227
# RendaTotal             0.970123   0.967987    1.000000           -0.383583
# RendaMediaFamiliar    -0.555408  -0.557227   -0.383583            1.000000
# RendaPerCapita        -0.539034  -0.544579   -0.361549            0.988081
# MatriculasEscolares    0.933737   0.934398    0.830117           -0.684872
# Empregos               0.948920   0.946595    0.923540           -0.565823
# ViagensDeBicicleta     0.118380   0.114125    0.283511            0.157942
#
#                      RendaPerCapita  MatriculasEscolares  Empregos  \
# Domicilios                -0.539034             0.933737  0.948920
# Populacao                 -0.544579             0.934398  0.946595
# RendaTotal                -0.361549             0.830117  0.923540
# RendaMediaFamiliar         0.988081            -0.684872 -0.565823
# RendaPerCapita             1.000000            -0.676705 -0.540224
# MatriculasEscolares       -0.676705             1.000000  0.884795
# Empregos                  -0.540224             0.884795  1.000000
# ViagensDeBicicleta         0.199190            -0.220853  0.088006
#
#                      ViagensDeBicicleta
# Domicilios                     0.118380
# Populacao                      0.114125
# RendaTotal                     0.283511
# RendaMediaFamiliar             0.157942
# RendaPerCapita                 0.199190
# MatriculasEscolares           -0.220853
# Empregos                       0.088006
# ViagensDeBicicleta             1.000000

# %%
plt.figure()
sns.heatmap(correlacoes, annot=True);

# %%
#ANÁLISE DA NORMALIDADE
stats.probplot(df['ViagensDeBicicleta'], dist="norm", plot=plt)
plt.title("Normal Q-Q plot")
plt.show()

# %%
plt.scatter(df.Domicilios,df.ViagensDeBicicleta)
plt.title('Correlação')
plt.xlabel('Domicilios')
plt.ylabel('VigensDeBicicleta')
plt.grid(True)
plt.show()
